# %% [markdown]
# # Discrete Math 2: Lecture 3 Assignment
# ##### by Johnvir Junsen S. Malazarte :D
# ##### BS Computer Science - 1
# ##### Instructor: Gerard Ompad

# %% [markdown]
# ________________________________________________________________________________________________________________

# %% [markdown]
# # Programming Assignment :

# %% [markdown]
# #### I. GRAPHS
# This is a graph. It consists of vertices/nodes and edges that connect these vertices. They're used to model pairwise relations between objects.

# %%
import matplotlib.pyplot as plt
import networkx as nx

mySeed = 360

node_names = ['J', 'U', 'N', 'S', 'E', 'N']
name_map = {i: name for i, name in enumerate(node_names)}

G = nx.gnm_random_graph(len(node_names), 5, seed=mySeed)
G = nx.relabel_nodes(G, name_map)
pos = nx.spring_layout(G, seed=mySeed)

nx.draw(G, pos=pos, with_labels=True, node_color='gray', node_size=1000)
plt.title("Example (Graph) :")
plt.show()

# %% [markdown]
# #### II. DIRECTED GRAPHS
# This is a directed graph (DiGraph) because its edges have clear directions, showing the flow or one-way relationships between nodes, which sets it apart from undirected graphs.

# %%
import matplotlib.pyplot as plt
import networkx as nx

mySeed = 20

node_names = ['J', 'O', 'H', 'N', 'S']
name_map = {i: name for i, name in enumerate(node_names)}

G = nx.gnm_random_graph(len(node_names), 4, seed=mySeed, directed=True)
G = nx.relabel_nodes(G, name_map)
pos = nx.spring_layout(G, seed=mySeed)

nx.draw(G, pos=pos, with_labels=True, node_color='gray', node_size=1000, arrowsize=20)
plt.title("Example (DiGraph):")
plt.show()

# %% [markdown]
# #### III. SIMPLE GRAPHS
# This is a simple graph because it doesn't have loops or multiple edges between the same pair of vertices.

# %%
import matplotlib.pyplot as plt
import networkx as nx

mySeed = 50

node_names = ['M', 'E', 'K', 'U', 'S']
name_map = {i: name for i, name in enumerate(node_names)}

G = nx.gnm_random_graph(len(node_names), 5, seed=mySeed)
G = nx.relabel_nodes(G, name_map)

# Draw the graph
pos = nx.spring_layout(G, seed=mySeed)
nx.draw(G, pos=pos, with_labels=True, node_color='gray', node_size=1500)
plt.title("Example (Simple Graph):")
plt.show()

# %% [markdown]
# #### IV. COMPLETE GRAPHS
# This is a complete graph. Each different pair of nodes in the graph is connected by exactly one edge, making it a fully connected network where all nodes are directly linked.

# %%
import matplotlib.pyplot as plt
import networkx as nx

mySeed = 50

node_names = ['C', 'L', 'O', 'V', 'E']
name_map = {i: name for i, name in enumerate(node_names)}
G = nx.complete_graph(len(node_names))
G = nx.relabel_nodes(G, name_map)

pos = nx.spring_layout(G, seed=9875)
nx.draw(G, pos=pos, with_labels=True, node_color='gray', node_size=1500)
plt.title("Example (Complete Graph):")
plt.show()

# %% [markdown]
# #### V. BIPARTITE GRAPHS
# The created graph is bipartite because its vertices can be divided into two separate sets where no two vertices within the same set are connected by an edge.

# %%
import matplotlib.pyplot as plt
import networkx as nx

kabit_network = nx.Graph()
kabit_network.add_nodes_from(['John','Vir','Malz'], bipartite=0)
kabit_network.add_nodes_from(['Althea','Mea'], bipartite=1)
kabit_network.add_edges_from([('John','Althea'), ('John','Mea')
                              , ('Vir','Althea'), ('Vir','Mea')
                              , ('Malz','Althea'), ('Malz','Mea')])

top = nx.bipartite.sets(kabit_network)[0]
pos = nx.bipartite_layout(kabit_network, top)
nx.draw(kabit_network, pos=pos, with_labels=True, node_color=['gray','gray','gray','yellow','yellow'], node_size=1000)
plt.show()

# %% [markdown]
# #### VI. SUBGRAPHS
# Subgraphs of a graph are graphs formed by selecting a subset of the vertices and edges from the original graph.

# %%
import matplotlib.pyplot as plt
import networkx as nx

mySeed = 60

node_names = ['H', 'E', 'A', 'L', 'E', 'R']
name_map = {i: name for i, name in enumerate(node_names)}
G = nx.gnm_random_graph(len(node_names), 7, seed=mySeed)
G = nx.relabel_nodes(G, name_map)

pos = nx.spring_layout(G, seed=mySeed)
nx.draw(G, pos=pos, with_labels=True, node_color='gray', node_size=1500)

subgraph_nodes = ['H', 'E', 'A']
subgraph = G.subgraph(subgraph_nodes)

nx.draw(subgraph, pos=pos, with_labels=True, node_color='skyblue', node_size=2000, edge_color='skyblue')
plt.title('A Graph (gray) and its Subgraph (skyblue)')
plt.show()

# %% [markdown]
# #### VII. DEGREE OF A VERTEX
# The degree of a vertex in a graph is how many edges are connected to it.

# %%
import matplotlib.pyplot as plt
import networkx as nx

mySeed = 20

node_names = ['A', 'B', 'C', 'D', 'E']
name_map = {i: name for i, name in enumerate(node_names)}
G = nx.gnm_random_graph(len(node_names), 5, seed=mySeed)
G = nx.relabel_nodes(G, name_map)

pos = nx.spring_layout(G, seed=mySeed)
nx.draw(G, pos=pos, with_labels=True, node_color='gray', node_size=1000)
plt.title("Sample graph for calculating the Degree of a Vertex")
plt.show()

# %% [markdown]
# | Vertex | Degree |
# |--------|--------|
# |   A    |   3    |
# |   B    |   3    |
# |   C    |   2    |
# |   D    |   1    |
# |   E    |   1    |
# | Total  |   10   |

# %% [markdown]
# #### VIII. HANDSHAKE THEOREM
# It states that in any finite undirected graph, the sum of the degrees of all vertices is twice the number of edges.
# Equation:
#
# $∑​deg(v)=2e$, such that deg(v) = degree of a vertex, and e = total number of edges
#
# Example from the Previous Graph:
#
# $Edges(e) = 5$
#
# $TotalDegrees(t) = 10$
#
# Thus,
#
# $t=2(5)=10$

# %% [markdown]
# #### IX. TRAVELLING IN A GRAPH
# Travelling in a graph refers to moving from one vertex to another following the edges, either in a specific order or optimizing a certain criterion like distance or cost.

# %%
import matplotlib.pyplot as plt
import networkx as nx

mySeed = 60
node_names = ['Portal', 'Bunzel', 'SMED', 'PE', 'LRC', 'MR']
name_map = {i: name for i, name in enumerate(node_names)}
G = nx.gnm_random_graph(len(node_names), 7, seed=mySeed)
G = nx.relabel_nodes(G, name_map)

# Draw the graph
pos = nx.spring_layout(G, seed=3)
nx.draw(G, pos=pos, with_labels=True, node_color='gray', node_size=1500)
plt.text(0.5, 0, "* Walk - From PE to LRC: PE->Portal->MR->Portal->LRC\n"
         "* Trail - From PE to LRC: PE->Portal->MR->LRC\n"
         "* Path - From PE to LRC: PE->Portal->SMED->Bunzel->LRC\n"
         "* Closed Walk - From PE to PE: Portal->SMED->Bunzel->MR->Portal->PE\n"
         "* Circuit - From Portal to Portal: Portal->SMED->Bunzel->MR->Portal\n"
         "* Simple Circuit - From Bunzel to Bunzel: Bunzel->SMED->Portal->F->Bunzel")
plt.title("TRAVELLING IN A GRAPH")
plt.show()

# %% [markdown]
# #### X. CONNECTEDNESS OF A GRAPH
# A graph is connected if there is a path between every pair of vertices in the graph.

# %%
import matplotlib.pyplot as plt
import networkx as nx

mySeed = 70

node_names = ['E', 'F', 'G', 'H']
name_map = {i: name for i, name in enumerate(node_names)}
G = nx.gnm_random_graph(len(node_names), 5, seed=mySeed)
G = nx.relabel_nodes(G, name_map)

pos = nx.spring_layout(G, seed=mySeed)
nx.draw(G, pos=pos, with_labels=True, node_color='gray', node_size=1000)
plt.title("Example (Connected Graph)")
plt.show()

# %% [markdown]
# #### XI. CONNECTED COMPONENTS
# Connected components of a graph are the maximal subgraphs in which any two vertices are connected to each other by paths, and which are connected to no additional vertices in the supergraph.

# %%
import matplotlib.pyplot as plt
import networkx as nx

mySeed = 45

node_names = ['L', 'M', 'N', 'O', 'P', 'Q']
name_map = {i: name for i, name in enumerate(node_names)}
G = nx.gnm_random_graph(len(node_names), 7, seed=mySeed)
G = nx.relabel_nodes(G, name_map)

pos = nx.spring_layout(G, seed=mySeed)
nx.draw(G, pos=pos, with_labels=True, node_color='skyblue', node_size=1500)

subgraph_nodes = ['F', 'E', 'D']
subgraph = G.subgraph(subgraph_nodes)

nx.draw(subgraph, pos=pos, with_labels=True, node_color='yellow', node_size=1500, edge_color='yellow')
plt.title('H (yellow) is a Connected Component of the Graph')
plt.show()

# %% [markdown]
# #### XII. EULER'S CIRCUIT
# An Eulerian circuit is a circuit that traverses each edge of a graph exactly once and returns to the starting vertex.
#
# ##### The graph is an Euler's Circuit because it satisfies the following conditions:
# - if every vertex in the graph has an even degree
# - the graph is connectededcted

# %%
import matplotlib.pyplot as plt
import networkx as nx

node_names = ['A', 'B', 'C', 'D', 'E', 'F']
edge_list = [("A", "B"), ("B", "C"), ("C", "D"), ("D", "E"), ("E", "F"), ("F", "A"), ("A", "C"), ("C", "E"), ("A", "E")]
G = nx.Graph()
G.add_nodes_from(node_names)
G.add_edges_from(edge_list)

euler_c = list(nx.eulerian_circuit(G))
pos = nx.spring_layout(G, seed=35)

nx.draw(G, pos=pos, with_labels=True, node_color='gray', node_size=500)
for u, v in euler_c:
    x0, y0 = pos[u]
    x1, y1 = pos[v]
    dx = x1 - x0
    dy = y1 - y0
    mid_x = (x0 + x1) / 2
    mid_y = (y0 + y1) / 2
    arrow_length_factor = 0.2
    plt.arrow(mid_x, mid_y, dx * arrow_length_factor, dy * arrow_length_factor, head_width=0.02, head_length=0.06, fc='red', ec='red')

plt.title("Graph with Eulerian Circuit and Arrows")
plt.show()

# %% [markdown]
# #### XIII. EULER'S TRAIL
# An Eulerian trail is a trail that traverses each edge of a graph exactly once but may or may not return to the starting vertex.

# %%
import matplotlib.pyplot as plt
import networkx as nx

node_names = ['Lacion', 'Liloan', 'Compostela', 'Danao', 'Jagobiao', 'Canduman']
edge_list = [('Lacion', 'Liloan'), ('Lacion', 'Canduman'), ('Compostela', 'Liloan'), ('Compostela', 'Danao'), ('Compostela', 'Canduman'), ('Jagobiao', 'Danao'), ('Jagobiao', 'Canduman')]
G = nx.Graph()
G.add_nodes_from(node_names)
G.add_edges_from(edge_list)

euler_path = list(nx.eulerian_path(G))
pos = nx.planar_layout(G)

nx.draw(G, pos=pos, with_labels=True, node_color='gray', node_size=500)
for u, v in euler_path:
        x0, y0 = pos[u]
        x1, y1 = pos[v]
        dx = x1 - x0
        dy = y1 - y0
        mid_x = (x0 + x1) / 2
        mid_y = (y0 + y1) / 2
        arrow_length_factor = 0.2
        plt.arrow(mid_x, mid_y, dx * arrow_length_factor, dy * arrow_length_factor, head_width=0.02, head_length=0.06, fc='red', ec='red')

plt.title("Graph with Eulerian Trail and Arrows")
plt.show()

# %% [markdown]
# #### XIV. HAMILTONIAN CIRCUITS
# A Hamiltonian circuit is a circuit that visits each vertex in a graph exactly once and returns to the starting vertex.
#
# ##### This circuit qualifies as a Hamiltonian Circuit due to the following criteria being met:
#
# - It traverses through every subset of the original grap
#
# - It maintains connectivity throughout the entire pth.
#
# - The number of edges in the path equals the number of verices.
#
# - Each vertex along the path has a degree of 2.

# %%
import matplotlib.pyplot as plt
import networkx as nx

def hamilton(G):
    F = [(G,[list(G.nodes())[0]])]
    n = G.number_of_nodes()
    while F:
        graph,path = F.pop()
        confs = []
        neighbors = (node for node in graph.neighbors(path[-1])
                     if node != path[-1]) #exclude self loops
        for neighbor in neighbors:
            conf_p = path[:]
            conf_p.append(neighbor)
            conf_g = nx.Graph(graph)
            conf_g.remove_node(path[-1])
            confs.append((conf_g,conf_p))
        for g,p in confs:
            if len(p)==n:
                return p
            else:
                F.append((g,p))
    return None

node_names = ['A', 'B', 'C', 'D']
edge_list = [("A", "B"), ("B", "C"), ("C", "D"), ("D", "A"), ("A", "C"), ("B", "D")]

G = nx.Graph()
G.add_nodes_from(node_names)
G.add_edges_from(edge_list)

# Find a Hamiltonian cycle

hamiltonian_c = list(hamilton(G))

# Visualize the graph
# Visualize the graph
pos = nx.spring_layout(G, seed=35)
nx.draw(G, pos=pos, with_labels=True, node_color='gray', node_size=500)

# Draw edges from Hamiltonian circuit
for i in range(len(hamiltonian_c) - 1):
    u, v = hamiltonian_c[i], hamiltonian_c[i + 1]
    nx.draw_networkx_edges(G, pos=pos, edgelist=[(u, v)], arrows=True, arrowsize=20, edge_color='red')

u, v = hamiltonian_c[-1], hamiltonian_c[0]
nx.draw_networkx_edges(G, pos=pos, edgelist=[(u, v)], arrows=True, arrowsize=20, edge_color='red')

plt.title("Graph with Hamiltonian Circuit")
plt.show()

# %% [markdown]
# #### XV. TRAVELLING SALESMAN PROBLEM

# %%
import matplotlib.pyplot as plt
import networkx as nx

node_names = ["A", "B", "C", "D"]
edges = [('A', 'B', {'weight': 30}),
         ('A', 'C', {'weight': 50}),
         ('A', 'D', {'weight': 40}),
         ('B', 'C', {'weight': 30}),
         ('B', 'D', {'weight': 35}),
         ('C', 'D', {'weight': 25})]

routes = [
    ['A', 'B', 'C', 'D', 'A'],
    ['A', 'B', 'D', 'C', 'A'],
    ['A', 'C', 'B', 'D', 'A'],
    ['A', 'C', 'D', 'B', 'A'],
    ['A', 'D', 'B', 'C', 'A']
]

fig, axs = plt.subplots(1, 5, figsize=(20, 4))

for i in range(5):
    G = nx.Graph()
    G.add_nodes_from(node_names)
    G.add_edges_from(edges)
    pos = nx.planar_layout(G)

    nx.draw_networkx_edge_labels(
        G, pos,
        edge_labels={('A', 'B'): '30',
                     ('A', 'C'): '50',
                     ('A', 'D'): '40',
                     ('B', 'C'): '30',
                     ('B', 'D'): '35',
                     ('C', 'D'): '25'},
        font_color='red', ax=axs[i]
    )

    nx.draw(G, pos=pos, with_labels=True, node_color='gray', node_size=1500, ax=axs[i])

    # Highlighting the specified route
    for j in range(len(routes[i]) - 1):
        nx.draw_networkx_edges(
            G, pos, edgelist=[(routes[i][j], routes[i][j + 1])],
            edge_color='red', width=2, ax=axs[i]
        )

    # Calculating the weight of the route
    weight = sum(G[routes[i][j]][routes[i][j + 1]]['weight'] for j in range(len(routes[i]) - 1))
    axs[i].set_title('Route {}'.format(i + 1))
    axs[i].text(0.5, -0.15, 'Weight: {}'.format(weight), horizontalalignment='center', verticalalignment='center',
                transform=axs[i].transAxes)

# Adjust layout
plt.tight_layout()
plt.gcf().canvas.manager.set_window_title("TRAVELLING SALESMAN PROBLEM")
plt.show()

# %% [markdown]
# As you can see from the five possible routes of the graph. The best possible and shortest path are:
#
# <table>
#     <tr>
#         <th>Route 2</th>
#         <td>A->B->D->C->A</td>
#     </tr>
#     <tr>
#         <th>Route 4</th>
#         <td>A->C->D->B->A</td>
#     </tr>
# </table>

# %% [markdown]
# #### TRAVELLING SALESMAN PROBLEM EXAMPLE

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Define the nodes and edges
nodes = ['SAS', 'SOE', 'SLG', 'SAFAD', 'USC']

edge_labels = {
    ('SAS', 'SOE'): 10,
    ('SAS', 'SLG'): 20,
    ('SAS', 'SAFAD'): 30,
    ('SAS', 'USC'): 40,
    ('SOE', 'SLG'): 50,
    ('SOE', 'SAFAD'): 60,
    ('SOE', 'USC'): 70,
    ('SLG', 'SAFAD'): 80,
    ('SLG', 'USC'): 90,
    ('SAFAD', 'USC'): 100,
    ('USC', 'SAFAD'): 5
}

# Convert edge labels to the desired format
formatted_edge_labels = {edge: "{} feet".format(weight) for edge, weight in edge_labels.items()}

# Define Hamilton circuits
hamilton_circuits = [
    ['SAS', 'SOE', 'SLG', 'SAFAD', 'USC', 'SAS'],
    ['SAS', 'SOE', 'SAFAD', 'USC', 'SLG', 'SAS'],
    ['SAS', 'SOE', 'USC', 'SLG', 'SAFAD', 'SAS'],
    ['SAS', 'USC', 'SAFAD', 'SLG', 'SOE', 'SAS'],
    ['SAS', 'USC', 'SAFAD', 'SOE', 'SLG', 'SAS']
]

# Plotting
fig, axs = plt.subplots(1, 5, figsize=(20, 4))

for i in range(5):
    G = nx.Graph()
    G.add_nodes_from(nodes)

    # Add edges with formatted labels
    for edge, label in formatted_edge_labels.items():
        G.add_edge(edge[0], edge[1], weight=edge_labels[edge])

    pos = nx.circular_layout(G)

    nx.draw_networkx_edge_labels(
        G, pos,
        edge_labels=formatted_edge_labels,
        font_color='red', ax=axs[i]
    )

    nx.draw(G, pos=pos, with_labels=True, node_color='gray', node_size=1500, ax=axs[i])

    # Highlighting the specified Hamilton circuit
    for j in range(len(hamilton_circuits[i]) - 1):
        nx.draw_networkx_edges(
            G, pos, edgelist=[(hamilton_circuits[i][j], hamilton_circuits[i][j + 1])],
            edge_color='red', width=2, ax=axs[i]
        )

    # Calculating and displaying the weight of the route
    weight = sum(G[hamilton_circuits[i][j]][hamilton_circuits[i][j + 1]]['weight'] for j in range(len(hamilton_circuits[i]) - 1))
    axs[i].set_title('Route {}'.format(i + 1))
    axs[i].text(0.5, -0.15, 'Weight: {}'.format(weight), horizontalalignment='center', verticalalignment='center',
                transform=axs[i].transAxes)

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# As you can see from the five possible routes of the graph. The best possible and shortest path is:
#
# <table>
#     <tr>
#         <th>Route 5</th>
#         <td>SAS -> USC -> SAFAD -> SOE -> SLG -> SAS</td>
#     </tr>
# </table>

# %% [markdown]
# ## Johnvir Junsen S. Malazarte :D
